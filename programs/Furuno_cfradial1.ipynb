# %% [markdown]
# # Furuno CFRadial1 Data

# %%
import wradlib as wrl
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as pl
import numpy as np
import xarray as xr
try:
    get_ipython().magic("matplotlib inline")
except:
    pl.ion()

# %%
fpath = 'radar_data_examples/CFRadial/0087_20210831/0087_20210831_040000.nc' #This path is for the Furuno data.

f = wrl.util.get_wradlib_data_file(fpath)
vol = wrl.io.open_cfradial1_dataset(f)
