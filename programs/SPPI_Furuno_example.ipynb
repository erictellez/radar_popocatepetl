# %% [markdown]
# ## Plot SPPI example file from Furuno radar
#
# Almost all the code I did copy from wradlib_plot_ppi_example.ipynb

# %%
import numpy as np
import matplotlib.pyplot as pl
import wradlib
import warnings
warnings.filterwarnings('ignore')
try:
    get_ipython().magic("matplotlib inline")
except:
    pl.ion()

# %%
filename = wradlib.util.get_wradlib_data_file('radar_data_examples/SPPI/0087_20201230_054548_001.sppi')
print(filename)
# Out:
# C:\Users\ERICK\Desktop\RADAR\radar_data_examples\SPPI\0087_20201230_054548_001.sppi

# %%
img, meta = wradlib.io.read_rainbow(filename) #It seems that none of the functions of .io can read this kind of file .sppi
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-8d83a4fb0764> in <module>
# ----> 1 img, meta = wradlib.io.read_rainbow(filename)
#
# ~\anaconda3\envs\wradlib\lib\site-packages\wradlib\io\rainbow.py in read_rainbow(filename, loaddata)
#     429     """
#     430     with util._open_file(filename) as f:
# --> 431         rbdict = get_rb_header(f)
#     432         if loaddata:
#     433             rbdict = get_rb_blobs_from_file(f, rbdict)
#
# ~\anaconda3\envs\wradlib\lib\site-packages\wradlib\io\rainbow.py in get_rb_header(fid)
#     392         line = fid.readline()
#     393         if len(line) == 0:
# --> 394             raise IOError("WRADLIB: Rainbow Fileheader Corrupt")
#     395
#     396     xmltodict = util.import_optional("xmltodict")
#
# OSError: WRADLIB: Rainbow Fileheader Corrupt
